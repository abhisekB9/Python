# %%
#Decision Making In Python

# %%
amount = 5000
location = "international"

if amount > 3000:
    if location == "international":
        print("Flag as high-risk transaction.")
    else:
        print("Review manually.")
else:
    print("Transaction looks normal.")
# Out:
# Flag as high-risk transaction.

# %%
#Define Arrays

# %%
numbers =[1,2,3,4,5]
print(numbers[2])

numbers[2]=10
print(numbers)

numbers.append(6)
print(numbers)
# Out:
# 3
# [1, 2, 10, 4, 5]
# [1, 2, 10, 4, 5, 6]

# %%
#Dictionary(Maps)

# %%
world_cups = {2019 : ['England', 'New Zealand'], 2015:["Australia", "New Zealand"], 2011 : ["India", "Sri Lanka"], 2007: ["Australia", "Sri Lanka"], 2003: ["Australia", "India"]}

year = int(input("Enter year to check New Zealand made it to Finals in 20th century : "))

if year in world_cups :
    if "New Zealand" in world_cups[year] :
        print("New Zealand made it to Finals")
    else:
        print("New Zealand could not make it to Finals")
        
else:
    print("World cup wasn't played in", year)
# Out:
# Enter year to check New Zealand made it to Finals in 20th century :  2015
# New Zealand made it to Finals

# %%
#Loops and Iteration In Python

# %%
for i in range(5):
   print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
fruits =['banana', 'apple']
for i in fruits:
    print(i)
# Out:
# banana
# apple

# %%
count = 0
while(count!=5):
    print(count)
    count = count +1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
fruits =['banana', 'apple', 'orange']
for i in fruits:
    if(i=='apple'):
        break
    elif(i=='orange'):
        continue
    else:
        print(i)
# Out:
# banana

# %%
square=[x**2 for x in range(5)]
print(square)
# Out:
# [0, 1, 4, 9, 16]

# %%
dic={x:x**2 for x in range(2,21) if x%2==0}
print(dic)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100, 12: 144, 14: 196, 16: 256, 18: 324, 20: 400}

# %%
#Function In Python 
#def function_name(parameters):
#    return something

# %%
def sum(x):
    print(x**2)
sum(4)
# Out:
# 16

# %%
def hello(name="world"):
       print(f"Hello,{name}")
hello()
hello("abhi")
# Out:
# Hello,world
# Hello,abhi

# %%
square = lambda x:x*x
square(3)
# Out:
# 9

# %%
#Map,Filter, Reduce In Python

# %%
numbers =[1,2,3,4,5]
result = map(lambda x: x*2 ,numbers)
print(list(result))
# Out:
# [2, 4, 6, 8, 10]

# %%
numbers =[1,2,3,4,5]
result = filter(lambda x: x%2==0 ,numbers)
print(list(result))
# Out:
# [2, 4]

# %%
from functools import reduce
numbers =[1,2,3,4,5]
result = reduce(lambda x,y: x+y ,numbers)
print(result)
# Out:
# 15

# %%
#OOPS In python

# %%
#Defining a Class and Object
class Car:
    def __init__(self, brand, engine):
        self.brand = brand
        self._engine = engine #private method
        

    def display(self):
        print(f"Car brand is {self.brand} and engine is {self._engine}")

car = Car("volvo", "bmw")
car.display()
# Out:
# Car brand is volvo and engine is bmw

# %%
#Inheritance
class Animal:
    def speak(self):
        print("speak")

class Dog(Animal):
    def speak(self):
        print("bark")    
        
dog = Dog()
dog.speak()
# Out:
# bark

# %%
#Abstraction
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def speak(self):
        pass

class Dog(Animal):
    def __init__(self, voice):
        self.voice = voice

    def speak(self):
        return self.voice
        

dog = Dog("bark")
print(dog.speak())
# Out:
# bark
